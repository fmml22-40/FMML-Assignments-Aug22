# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2023-05-24 16:12:42--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   152MB/s    in 0.5s
#
# 2023-05-24 16:12:47 (152 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3679 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2703 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 5  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 7  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 19359   1304.3844v2  This is the Proceedings of the Fourteenth Conf...    cs
# 6725   1705.08618v1  Contextual bandits are a form of multi-armed b...  stat
# 36545  1502.01972v1  We consider a dynamic vehicle routing problem ...    cs
# 22717  1705.06364v1  We develop a new method called Discriminated H...  stat
# 2000    1311.1761v1  Sophisticated multilayer neural networks have ...    cs
# ...             ...                                                ...   ...
# 20069   1407.3211v1  In this paper, concept of possibility neutroso...    cs
# 21958   1007.1075v1  A popular method for selecting the number of c...  stat
# 2339    1204.0033v1  Relational data representations have become an...  stat
# 21522   0902.3453v1  We present the first tree-based regressor whos...  stat
# 24248   1112.4164v5  A fundamental task in human chromosome analysi...    cs
#
#                                                    title  year  \
# 19359  Proceedings of the Fourteenth Conference on Un...  2013
# 6725          Multi-Task Learning for Contextual Bandits  2017
# 36545  A Multistage Stochastic Programming Approach t...  2015
# 22717  Learning Gaussian Graphical Models Using Discr...  2017
# 2000   Exploring Deep and Recurrent Architectures for...  2013
# ...                                                  ...   ...
# 20069  Possibility neutrosophic soft sets with applic...  2014
# 21958                  Clustering Stability: An Overview  2010
# 2339   Transforming Graph Representations for Statist...  2012
# 21522  Escaping the curse of dimensionality with a tr...  2009
# 24248  A Geometric Approach For Fully Automatic Chrom...  2011
#
#                                                 keywords
# 19359  [proceedings, fourteenth, conference, uncertai...
# 6725   [contextual, predictive, information, personal...
# 36545  [consider, stochastic, customers, customers, s...
# 22717  [discriminated, graphical, graphical, providin...
# 2000   [sophisticated, multilayer, networks, achieved...
# ...                                                  ...
# 20069  [possibility, neutrosophic, operations, proper...
# 21958  [selecting, clusters, stability, arguments, cl...
# 2339   [relational, representations, increasingly, im...
# 21522  [regressor, convergence, intrinsic, dimension,...
# 24248  [fundamental, chromosome, analysis, chromosome...
#
# [5105 rows x 6 columns]

# %%
df['keywords']
# Out:
# 19359    [proceedings, fourteenth, conference, uncertai...
# 6725     [contextual, predictive, information, personal...
# 36545    [consider, stochastic, customers, customers, s...
# 22717    [discriminated, graphical, graphical, providin...
# 2000     [sophisticated, multilayer, networks, achieved...
#                                ...
# 33416    [studying, optimization, estimation, distribut...
# 6777     [traditional, statistical, analysis, performed...
# 5639     [recently, substantial, interest, spectral, le...
# 30618    [paradigm, tracking, tracking, detection, avai...
# 11143    [randomized, algorithm, computing, approximati...
# Name: keywords, Length: 6382, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 11698 words.
# Out of those 3320 have over 5 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="9a330ea5-33e2-46a1-8349-d381a6be996b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9a330ea5-33e2-46a1-8349-d381a6be996b")) {                    Plotly.newPlot(                        "9a330ea5-33e2-46a1-8349-d381a6be996b",                        [{"x":["intelligence","artificial","uncertainty","conference","proceedings","interpret","algorithms","algorithm","establish","confidence","predictive","information","recommendation","corresponding","learning","different","problems","applications","quantify","demonstrate","contexts","placement","estimating","framework","presence","effective","describe","advantages","leverage","performance","similarity","contextual","personalized","similarities","meaningful","customers","solutions","competitive","approach","experiments","vehicles","strategy","instances","provided","constraints","assessment","programming","particular","benchmarks","existing","probabilistic","efficiently","approximating","decisions","integrates","knowledge","customer","decision","requests","services","stochastic","choosing","heuristic","likelihood","extended","introduce","consider","providing","graphical","precision","estimate","measures","situations","degenerate","gaussian","successful","networks","locomotion","reinforcement","continuous","architectures","differences","parameters","allowing","sophisticated","thousands","directions","achieved","multiple","comparing","successfully","directly","supervised","pipeline","controllers","exploring","recurrent","techniques","application","perception","experimental","previous","dimensional","represent","multilayer","analysis","hierarchies","description","complete","designed","quantification","whenever","possible","operators","variational","presents","complexity","interpretation","restrictions","inference","difference","randomly","measured","obtained","generated","generating","exploration","empirically","following","diffusion","discrete","exploitation","experiences","scenarios","specific","construct","scenario","sequence","statistics","preferences","expected","selecting","maximize","exchange","broadcast","acoustic","evolutionary","univariate","addressed","respective","generalization","strategies","solution","instantaneous","relevant","efficacy","optimization","previously","evaluated","recursively","efficient","illustrate","simulated","research","captured","posterior","employed","generalizing","frequently","identification","includes","innovation","distribution","classical","combines","approximated","consists","highlight","improvements","sampling","particle","advancements","published","completely","filtering","particles","calculated","nonlinear","variable","selection","nonstationary","realizations","datasets","challenges","theoretical","spatially","generative","traditional","probabilities","capabilities"],"y":[89,150,91,10,5,21,632,864,42,45,55,740,26,133,1312,788,505,432,24,589,40,6,59,566,73,274,218,90,60,944,170,47,14,30,60,14,157,114,1030,671,29,140,112,119,151,44,139,290,93,445,160,169,25,51,28,366,13,186,10,26,131,26,60,76,95,357,204,87,60,84,101,108,63,4,108,72,746,7,120,122,131,62,254,87,30,33,41,180,346,67,93,175,203,54,9,44,127,408,255,50,407,292,191,129,15,580,14,71,110,172,20,13,226,40,63,184,231,61,12,243,81,41,51,237,179,114,63,84,86,24,79,19,15,96,259,94,55,180,60,33,76,52,32,23,8,24,62,4,31,22,119,100,242,5,132,35,328,90,149,12,417,77,68,325,67,45,72,11,33,103,60,8,242,108,81,16,104,22,123,111,21,6,35,43,66,8,28,56,87,183,3,3,500,140,149,29,126,196,47,41],"type":"bar"},{"x":["intelligence","artificial","uncertainty","conference","proceedings","interpret","algorithms","algorithm","establish","confidence","predictive","information","recommendation","corresponding","learning"," ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (3320,), (3320, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7658574784651527

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Beyond</span> <span style='background-color:rgba(0, 255, 0, 0.5172413793103448);'>Counting</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Comparisons</span> <span style=''>of</span> <span style=''>Density</span> <span style=''>Maps</span> <span style=''>for</span> <span style=''>Crowd</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Analysis</span> <span style=''>Tasks</span> <span style='background-color:rgba(0, 255, 0, 0.5172413793103448);'>Counting</span> <span style='background-color:rgba(0, 255, 0, 0.534675615212528);'>Detection</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.5929203539823009);'>Tracking</span> <br/><br/><span style=''>For</span> <span style=''>crowded</span> <span style=''>scenes</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>accuracy</span> <span style=''>of</span> <span style=''>object</span> <span style=''>based</span> <span style='background-color:rgba(0, 255, 0, 0.5795454545454546);'>computer</span> <span style=''>vision</span> <span style=''>methods</span> <span style=''>declines</span> <span style=''>when</span> <span style=''>the</span> <span style=''>images</span> <span style=''>are</span> <span style=''>low</span> <span style='background-color:rgba(0, 255, 0, 0.6503496503496504);'>resolution</span> <span style=''>and</span> <span style=''>objects</span> <span style=''>have</span> <span style=''>severe</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>occlusions</span> <span style=''>Taking</span> <span style='background-color:rgba(0, 255, 0, 0.5172413793103448);'>counting</span> <span style=''>methods</span> <span style=''>for</span> <span style=''>example</span> <span style=''>almost</span> <span style=''>all</span> <span style=''>the</span> <span style=''>recent</span> <span style=''>state</span> <span style=''>of</span> <span style=''>the</span> <span style=''>art</span> <span style='background-color:rgba(0, 255, 0, 0.5172413793103448);'>counting</span> <span style=''>methods</span> <span style=''>bypass</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>explicit</span> <span style='background-color:rgba(0, 255, 0, 0.534675615212528);'>detection</span> <span style=''>and</span> <span style=''>adopt</span> <span style='background-color:rgba(255, 0, 0, 0.4952919020715631);'>regression</span> <span style=''>based</span> <span style=''>methods</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>directly</span> <span style=''>count</span> <span style=''>the</span> <span style=''>objects</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>interest</span> <span style=''>Among</span> <span style='background-color:rgba(255, 0, 0, 0.4952919020715631);'>regression</span> <span style=''>based</span> <span style=''>methods</span> <span style=''>density</span> <span style=''>map</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>estimation</span> <span style=''>where</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style=''>objects</span> <span style=''>inside</span> <span style=''>a</span> <span style=''>subregion</span> <span style=''>is</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>integral</span> <span style=''>of</span> <span style=''>the</span> <span style=''>density</span> <span style=''>map</span> <span style=''>over</span> <span style=''>that</span> <span style=''>subregion</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>especially</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>promising</span> <span style=''>because</span> <span style=''>it</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>preserves</span> <span style=''>spatial</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>information</span> <span style=''>which</span> <span style=''>make ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Interpreting</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Classifiers</span> <span style=''>through</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Attribute</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Interactions</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Datasets</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>work</span> <span style=''>we</span> <span style=''>present</span> <span style=''>the</span> <span style=''>novel</span> <span style=''>ASTRID</span> <span style=''>method</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>investigating</span> <span style=''>which</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>attribute</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>interactions</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classifiers</span> <span style=''>exploit</span> <span style=''>when</span> <span style=''>making</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predictions</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Attribute</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>interactions</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>tasks</span> <span style=''>mean</span> <span style=''>that</span> <span style=''>two</span> <span style=''>or</span> <span style=''>more</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>attributes</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>together</span> <span style=''>provide</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>stronger</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>evidence</span> <span style=''>for</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>particular</span> <span style=''>class</span> <span style=''>label</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Knowledge</span> <span style=''>of</span> <span style=''>such</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>interactions</span> <span style=''>makes</span> <span style=''>models</span> <span style=''>more</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interpretable</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>revealing</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>associations</span> <span style=''>between</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>attributes</span> <span style=''>This</span> <span style=''>has</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>applications</span> <span style=''>eg</span> <span style=''>in</span> <span style=''>pharmacovigilance</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>identify</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>interactions</span> <span style=''>between</span> <span style=''>drugs</span> <span style=''>or</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>bioinformatics</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>investigate</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>associations</span> <span style=''>between</span> <span style=''>single</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nucleotide</span> <span style=''>polymorphisms</span> <span style=''>We</span> <span style=''>also</span> <span style=''>show</span> <span style=''>how</span> <span style=''>the</span> <span style=''>found</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>attribute</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>partitioning</span> <span style=''>is</span> <span style=''>related</span> <span style=''>to</span> <span style=''>a</span> <span style=' ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>On</span> <span style=''>the</span> <span style=''>Power</span> <span style=''>of</span> <span style=''>Over</span> <span style='background-color:rgba(255, 0, 0, 0.8461538461538463);'>parametrization</span> <span style=''>in</span> <span style=''>Neural</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Networks</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Quadratic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Activation</span> <br/><br/><span style=''>We</span> <span style=''>provide</span> <span style=''>new</span> <span style='background-color:rgba(255, 0, 0, 0.35913978494623655);'>theoretical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>insights</span> <span style=''>on</span> <span style=''>why</span> <span style=''>over</span> <span style='background-color:rgba(255, 0, 0, 0.8461538461538463);'>parametrization</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3173076923076923);'>effective</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>learning</span> <span style=''>neural</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>networks</span> <span style=''>For</span> <span style=''>a</span> <span style=''>k</span> <span style=''>hidden</span> <span style=''>node</span> <span style=''>shallow</span> <span style=''>network</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>quadratic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>activation</span> <span style=''>and</span> <span style=''>n</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>training</span> <span style=''>data</span> <span style=''>points</span> <span style=''>we</span> <span style=''>show</span> <span style=''>as</span> <span style=''>long</span> <span style=''>as</span> <span style=''>k</span> <span style=''>ge</span> <span style=''>sqrt2n</span> <span style=''>over</span> <span style='background-color:rgba(255, 0, 0, 0.8461538461538463);'>parametrization</span> <span style=''>enables</span> <span style=''>local</span> <span style=''>search</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>to</span> <span style=''>find</span> <span style=''>a</span> <span style=''>emphglobally</span> <span style=''>optimal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>solution</span> <span style=''>for</span> <span style=''>general</span> <span style=''>smooth</span> <span style=''>and</span> <span style=''>convex</span> <span style=''>loss</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>functions</span> <span style=''>Further</span> <span style=''>despite</span> <span style=''>that</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>parameters</span> <span style=''>may</span> <span style=''>exceed</span> <span style=''>the</span> <span style=''>sample</span> <span style=''>size</span> <span style=''>using</span> <span style=''>theory</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.5789473684210527);'>Rademacher</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>complexity</span> <span style=''>we</span> <span style=''>show</span> <span style=''>with</span> <span style=''>weight</span> <span style=''>decay</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>solution</span> <span style=''>also</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generalizes</span> <span style=''>well</span> <span style=''>if</span> <span style=''>the</span> <span style=''>data</span> <span style=''>is</span> <span style=''>sampled</span> <span style=''>from</span> <span style=''>a</span> <span style=''>regular</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distribution</span> <span style=''>such</span> <span style=''>as</s ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Generative</span> <span style=''>Models</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Stochastic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Processes</span> <span style=''>Using</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Convolutional</span> <span style=''>Neural</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Networks</span> <br/><br/><span style=''>The</span> <span style=''>present</span> <span style=''>paper</span> <span style=''>aims</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>demonstrate</span> <span style=''>the</span> <span style=''>usage</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Convolutional</span> <span style=''>Neural</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Networks</span> <span style=''>as</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generative</span> <span style=''>model</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stochastic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>processes</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>enabling</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>researchers</span> <span style=''>from</span> <span style=''>a</span> <span style=''>wide</span> <span style=''>range</span> <span style=''>of</span> <span style=''>fields</span> <span style=''>(such</span> <span style=''>as</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>quantitative</span> <span style=''>finance</span> <span style=''>and</span> <span style=''>physics)</span> <span style=''>to</span> <span style=''>develop</span> <span style=''>a</span> <span style=''>general</span> <span style=''>tool</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>forecasts</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>simulations</span> <span style=''>without</span> <span style=''>the</span> <span style=''>need</span> <span style=''>to</span> <span style=''>identifyassume</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>specific</span> <span style=''>system</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structure</span> <span style=''>or</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimate</span> <span style=''>its</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameters</span> <br/><br/>

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	knowledge (0.12521382141635307)
# 	architecture (0.08860759493670886)
# 	computer (0.09510776599384195)
# 	information (0.25316455696202533)
# 	detection (0.11734519329456038)
# 	different (0.2695860417379405)
# 	semantic (0.08860759493670886)
# 	recognition (0.13034553540882654)
# 	convolutional (0.14197742045843312)
# 	language (0.13855627779678412)
#
# Some Statistics words are:
# 	statistical (0.15673693858845097)
# 	theoretical (0.14482126489459213)
# 	distribution (0.1782768102658112)
# 	variables (0.1461961503208066)
# 	learning (0.5517873510540788)
# 	gaussian (0.15169569202566452)
# 	bayesian (0.1691109074243813)
# 	inference (0.20119156736938587)
# 	dimensional (0.1851512373968836)
# 	regression (0.18194317140238314)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="b7325676-70b0-4791-961d-289b51594c26" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b7325676-70b0-4791-961d-289b51594c26")) {                    Plotly.newPlot(                        "b7325676-70b0-4791-961d-289b51594c26",                        [{"x":["intelligence","artificial","uncertainty","conference","proceedings","interpret","algorithms","algorithm","establish","confidence","predictive","information","recommendation","corresponding","learning","different","problems","applications","quantify","demonstrate","contexts","placement","estimating","framework","presence","effective","describe","advantages","leverage","performance","similarity","contextual","personalized","similarities","meaningful","customers","solutions","competitive","approach","experiments","vehicles","strategy","instances","provided","constraints","assessment","programming","particular","benchmarks","existing","probabilistic","efficiently","approximating","decisions","integrates","knowledge","customer","decision","requests","services","stochastic","choosing","heuristic","likelihood","extended","introduce","consider","providing","graphical","precision","estimate","measures","situations","degenerate","gaussian","successful","networks","locomotion","reinforcement","continuous","architectures","differences","parameters","allowing","sophisticated","thousands","directions","achieved","multiple","comparing","successfully","directly","supervised","pipeline","controllers","exploring","recurrent","techniques","application","perception","experimental","previous","dimensional","represent","multilayer","analysis","hierarchies","description","complete","designed","quantification","whenever","possible","operators","variational","presents","complexity","interpretation","restrictions","inference","difference","randomly","measured","obtained","generated","generating","exploration","empirically","following","diffusion","discrete","exploitation","experiences","scenarios","specific","construct","scenario","sequence","statistics","preferences","expected","selecting","maximize","exchange","broadcast","acoustic","evolutionary","univariate","addressed","respective","generalization","strategies","solution","instantaneous","relevant","efficacy","optimization","previously","evaluated","recursively","efficient","illustrate","simulated","research","captured","posterior","employed","generalizing","frequently","identification","includes","innovation","distribution","classical","combines","approximated","consists","highlight","improvements","sampling","particle","advancements","published","completely","filtering","particles","calculated","nonlinear","variable","selection","nonstationary","realizations","datasets","challenges","theoretical","spatially","generative","traditional","probabilities","capabilities","reduction","furthermore","nonparametric","provides","document","therefore","clustering","modeling","assumption","mathematically","inherent","interest","processes","inherits","practical","revealed","subsampling","discover","dependent","additional","impractical","structure","synthetic","distributions","assigned","prediction","importantly","constraint","relational","documents","probability","specifically","simultaneously","represents","although","creation","reconstruction","performing","demonstrated","benchmark","unsupervised","location","architecture","limiting","features","recursive","desirable","challenging","feedforward","recently","fraction","flexible","convolutional","labeling","dependencies","hypothesize","weighting","statistical","parallelizable","microscopy","boundary","improves","electron","segmentation","multiscale","software","associated","properties","accuracy","compared","iterat ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	negativity
# 	volatility
# 	blockmodel
# 	mathbbrd
# 	elucidate
# 	gaussianity
# 	distributionally
# 	determinantal
# 	marginalization
# 	elliptical
# 	misspecified
# 	semiparametric
# 	quantiles
# 	quantile
# 	cytometry
# 	dendrogram
# 	debiased
# 	quadrature
# 	censoring
# 	logarithmically
# Some words which never appear in Statistics papers:
# 	locomotion
# 	broadcast
# 	utterance
# 	engineers
# 	subtasks
# 	multilingual
# 	manipulating
# 	annotating
# 	polarity
# 	landmark
# 	compilation
# 	ontology
# 	ontological
# 	narrative
# 	reaction
# 	nonmonotonic
# 	autonomously
# 	disambiguation
# 	postulates
# 	designer

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0721966205837174e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7376664056382146
